# %%
import pandas as pd
import numpy as np
import torch
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
import random
import os
import torch.nn as nn
from torch.nn.functional import softmax


# custom dataset class for our image data
class UCMercedDataset(Dataset):
    def __init__(self,class_list, root_dir, transforms=None):
        dataX=[]
        for i in class_list:
            for j in range(100):
                dataX.append(f'{i}{j:02}.tif')
        dataX=np.array(dataX)
        np.random.shuffle(dataX)
        
        self.dataX=dataX
        self.root_dir=root_dir
        self.transforms=transforms
        self.class_list={class_list[i]:i for i in range(len(class_list))}
    
    def __len__(self):
        return len(self.dataX)
    
    def __getitem__(self,index):
        imgName=self.dataX[index]
        imgPath=os.path.join(self.root_dir, imgName[:-6], imgName)
        image=Image.open(imgPath)
        y=torch.tensor(self.class_list[imgName[:-6]])
        if self.transforms:
            image=self.transforms(image)
        return(image,y)


def train(ep=5):
    # Training loop
    for epoch in range(ep):
        for i, (img,target) in enumerate(train_loader):
            img=img.to(device)
            target=target.to(device)

            out=model(img)
            loss=lossFunction(out,target)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            if(i%10==0):
                print(f'\033[30m {loss.item()}')
        print(f' \033[93m epoch {epoch+1} Finished\n\n')


# This is a helper function used only once to calculate the mean and std for the training data
def get_mean_std(loader):
    mean=0
    std=0
    total_image=0
    for i, _ in loader:
        batch_size=i.size(0)
        imgs=i.view(batch_size,i.size(1),-1)
        mean+=imgs.mean(2).sum(0)
        std+=imgs.std(2).sum(0)
        total_images=batch_size
    
    mean/=total_images
    std/=total_images
    return mean, std

# This is a helper function used to calculate the accuracy of the passed loader
def accuracy(loader, verbose=False):
    correct=0
    with torch.no_grad():
        for i, (img,target) in enumerate(loader):
            img=img.to(device)
            target=target.to(device)
            out=model(img)
            out=softmax(out,dim=1)
            for j in range(len(out)):
                if torch.argmax(out[j]) == target[j]:
                    if(verbose):
                        print(f'\033[92m target:{target[j]} prediction:{torch.argmax(out[j])} confidence:{round(torch.max(out[j]).item()*100,2)}%')
                    correct+=1
                else:
                    if(verbose):
                        print(f'\033[91m target: {target[j]} prediction: {torch.argmax(out[j])} confidence: {round(torch.max(out[j]).item()*100,2)}%')

    print(f'\033[94m Accuracy: {correct*100/(len(loader)*batch_size)}')


batch_size=32

# calculated mean and std of the entire data calculated using get_mean_std() helper function
mean=torch.tensor([62.4188, 62.6786, 62.6386])
std=torch.tensor([23.9611, 22.5873, 21.3868])

# Defining a custom transform pipeline
train_transform=transforms.Compose([
    transforms.Resize((256,256)),
    transforms.RandomInvert(0.6),
    transforms.RandomSolarize(0.6),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean,std=std),
#     transforms.ColorJitter(),
    
])

#Getting GPU support if available
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    



classes=os.listdir("/kaggle/input/ucmerced/UCMerced_LandUse/Images")
# randomly selecting 14 classes for training
classes_for_training=random.sample(classes, 14)
classes_left_out=list(set(classes)-set(classes_for_training))



data=UCMercedDataset(class_list=classes_for_training,
                               root_dir="/kaggle/input/ucmerced/UCMerced_LandUse/Images",
                               transforms=train_transform)

training_data, testing_data =random_split(data, [1000,400])

remaining_data=UCMercedDataset(class_list=classes_left_out,
                               root_dir="/kaggle/input/ucmerced/UCMerced_LandUse/Images",
                               transforms=train_transform)


# Dataloader for training dataset
train_loader=DataLoader(dataset=training_data, batch_size=batch_size,shuffle=True)
# Dataloader for testing dataset
test_loader=DataLoader(dataset=testing_data, batch_size=batch_size,shuffle=True)
# data loader for the untrainied classes
remaining_loader=DataLoader(dataset=remaining_data, batch_size=batch_size)




# loading the pretrained model for the resnet
model=torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=True)
num_fters=model.fc.in_features
# setting the last layer of the model to give output for the 14 classes 
model.fc=nn.Linear(num_fters, 14)
model=model.to(device)
# using cross entropy loss function
lossFunction=nn.CrossEntropyLoss()
# using adam optimizer
optimizer=torch.optim.Adam(model.parameters(), lr=0.0001)    


print("Training...")
train(ep=10)

# Training accuracy
accuracy(train_loader)
print(f"\033[30m Training accuracy\n\n")

# Test accuracy
accuracy(test_loader, verbose=True)
print(f"\033[30m Test accuracy\n\n")

# Accuracy for the classes which were not even in the training
accuracy(remaining_loader, verbose=True)
print("Accuracy on the classes which were not even used in the training process\n\n")

# 995
# 99.5
# 384
# 96.0
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Training...
#  2.825975179672241
#  1.632214903831482
#  0.9529239535331726
#  0.8187040686607361
#   epoch 1 Finished
#
#
#  0.6329565644264221
#  0.29506510496139526
#  0.38541123270988464
#  0.29911303520202637
#   epoch 2 Finished
#
#
#  0.11797478049993515
#  0.2875511348247528
#  0.22518481314182281
#  0.12293360382318497
#   epoch 3 Finished
#
#
#  0.03468773141503334
#  0.06378623098134995
#  0.08401776850223541
#  0.09371339529752731
#   epoch 4 Finished
#
#
#  0.07813192158937454
#  0.033857788890600204
#  0.0496072955429554
#  0.18473246693611145
#   epoch 5 Finished
#
#
#  0.030771616846323013
#  0.0761777013540268
#  0.033028095960617065
#  0.07644280046224594
#   epoch 6 Finished
#
#
#  0.016225477680563927
#  0.018037943169474602
#  0.013957143761217594
#  0.008556254208087921
#   epoch 7 Finished
#
#
#  0.029684484004974365
#  0.03706371411681175
#  0.034119877964258194
#  0.21516315639019012
#   epoch 8 Finished
#
#
#  0.018442748114466667
#  0.035950858145952225
#  0.009289397858083248
#  0.009316559880971909
#   epoch 9 Finished
#
#
#  0.0034640568774193525
#  0.04090943560004234
#  0.016282152384519577
#  0.06492733210325241
#   epoch 10 Finished
#
#
#  Accuracy: 97.65625
#  Training accuracy
#
#
#  target:13 prediction:13 confidence:99.97%
#  target:9 prediction:9 confidence:99.31%
#  target:8 prediction:8 confidence:99.76%
#  target:12 prediction:12 confidence:98.89%
#  target:13 prediction:13 confidence:99.94%
#  target:1 prediction:1 confidence:99.79%
#  target:8 prediction:8 confidence:64.12%
#  target:0 prediction:0 confidence:97.13%
#  target:12 prediction:12 confidence:99.99%
#  target:4 prediction:4 confidence:99.72%
#  target:5 prediction:5 confidence:99.68%
#  target:1 prediction:1 confidence:93.24%
#  target:10 prediction:10 confidence:95.25%
#  target:0 prediction:0 confidence:93.6%
#  target:7 prediction:7 confidence:99.96%
#  target:2 prediction:2 confidence:39.85%
#  target: 5 prediction: 2 confidence: 86.26%
#  target:1 prediction:1 confidence:44.56%
#  target:5 prediction:5 confidence:99.79%
#  target:4 prediction:4 confidence:99.53%
#  target:4 prediction:4 confidence:94.86%
#  target:1 prediction:1 confidence:81.75%
#  target:1 prediction:1 confidence:99.66%
#  target:7 prediction:7 confidence:98.8%
#  target:4 prediction:4 confidence:98.74%
#  target:9 prediction:9 confidence:99.69%
#  target:8 prediction:8 confidence:87.33%
#  target:6 prediction:6 confidence:89.21%
#  target:9 prediction:9 confidence:62.6%
#  target:1 prediction:1 confidence:99.55%
#  target:2 prediction:2 confidence:99.66%
#  target:0 prediction:0 confidence:99.96%
#  target:8 prediction:8 confidence:99.94%
#  target:1 prediction:1 confidence:99.94%
#  target:0 prediction:0 confidence:56.76%
#  target:2 prediction:2 confidence:98.73%
#  target:13 prediction:13 confidence:86.98%
#  target:3 prediction:3 confidence:99.92%
#  target:5 prediction:5 confidence:99.78%
#  target: 10 prediction: 6 confidence: 75.44%
#  target:6 prediction:6 confidence:97.82%
#  target:10 prediction:10 confidence:89.52%
#  target:4 prediction:4 confidence:99.68%
#  target:7 prediction:7 confidence:52.49%
#  target:4 prediction:4 confidence:97.54%
#  target:2 prediction:2 confidence:90.63%
#  target:9 prediction:9 confidence:80.45%
#  target:11 prediction:11 confidence:99.95%
#  target:10 prediction:10 confidence:96.62%
#  target:12 prediction:12 confidence:99.97%
#  target:0 prediction:0 confidence:99.31%
#  target:8 prediction:8 confidence:58.12%
#  target:5 prediction:5 confidence:99.38%
#  target:11 prediction:11 confidence:99.75%
#  target:5 prediction:5 confidence:99.94%
#  target:7 prediction:7 confidence:99.83%
#  target:7 prediction:7 confidence:98.51%
#  target:10 prediction:10 confidence:99.94%
#  target:9 prediction:9 confidence:59.08%
#  target:7 prediction:7 confidence:97.54%
#  target:7 prediction:7 confidence:99.07%
#  target:2 prediction:2 confidence:99.73%
#  target:3 prediction:3 confidence:99.36%
#  target:11 prediction:11 confidence:99.81%
#  target:10 prediction:10 confidence:99.91%
#  target:13 prediction:13 confidence:99.86%
#  target:8 prediction:8 confidence:98.69%
#  target:11 prediction:11 confidence:99.21%
#  target:7 prediction:7 confidence:99.94%
#  target:12 prediction:12 confidence:85.2%
#  target:5 prediction:5 confidence:99.91%
#  target:12 prediction:12 confidence:98.19%
#  target:13 prediction:13 confidence:99.59%
#  target:10 prediction:10 confidence:99.49%
#  target:9 prediction:9 confidence:93.36%
#  target:3 prediction:3 confidence:99.78%
#  target:13 prediction:13 confidence:99.87%
#  target:12 prediction:12 confidence:99.96%
#  target:12 prediction:12 confidence:95.32%
#  target:10 prediction:10 confidence:79.12%
#  target:2 prediction:2 confidence:97.81%
#  target: 12 prediction: 6 confidence: 48.28%
#  target:12 prediction:12 confidence:99.21%
#  target:0 prediction:0 confidence:99.88%
#  target:11 prediction:11 confidence:99.25%
#  target:9 prediction:9 confidence:99.97%
#  target:6 prediction:6 confidence:99.5%
#  target: 0 prediction: 3 confidence: 63.94%
#  target:10 prediction:10 confidence:98.9%
#  target:0 prediction:0 confidence:99.95%
#  target:10 prediction:10 confidence:92.32%
#  target:3 prediction:3 confidence:99.83%
#  target:11 prediction:11 confidence:99.8%
#  target:8 prediction:8 confidence:97.62%
#  target:7 prediction:7 confidence:99.79%
#  target:8 prediction:8 confidence:99.96%
#  target:1 prediction:1 confidence:80.66%
#  target:3 prediction:3 confidence:99.88%
#  target:7 prediction:7 confidence:99.29%
#  target:4 prediction:4 confidence:98.78%
#  target:2 prediction:2 confidence:99.61%
#  target:6 prediction:6 confidence:96.31%
#  target:3 prediction:3 confidence:99.98%
#  target:1 prediction:1 confidence:99.52%
#  target:1 prediction:1 confidence:62.87%
#  target:10 prediction:10 confidence:98.74%
#  target:2 prediction:2 confidence:96.3%
#  target:1 prediction:1 confidence:99.19%
#  target:12 prediction:12 confidence:99.07%
#  target:8 prediction:8 confidence:75.57%
#  target: 6 prediction: 12 confidence: 51.61%
#  target:8 prediction:8 confidence:97.51%
#  target: 1 prediction: 6 confidence: 95.8%
#  target:5 prediction:5 confidence:99.23%
#  target:4 prediction:4 confidence:99.59%
#  target:6 prediction:6 confidence:98.51%
#  target: 1 prediction: 5 confidence: 70.75%
#  target:4 prediction:4 confidence:99.78%
#  target:4 prediction:4 confidence:98.69%
#  target:2 prediction:2 confidence:99.45%
#  target:8 prediction:8 confidence:99.89%
#  target:9 prediction:9 confidence:97.73%
#  target:10 prediction:10 confidence:88.12%
#  target:13 prediction:13 confidence:99.82%
#  target:6 prediction:6 confidence:96.65%
#  target:8 prediction:8 confidence:99.97%
#  target:1 prediction:1 confidence:97.94%
#  target:1 prediction:1 confidence:88.86%
#  target:6 prediction:6 confidence:78.8%
#  target: 8 prediction: 11 confidence: 72.79%
#  target:8 prediction:8 confidence:98.65%
#  target:3 prediction:3 confidence:98.88%
#  target:8 prediction:8 confidence:98.32%
#  target:1 prediction:1 confidence:98.44%
#  target:11 prediction:11 confidence:99.75%
#  target:9 prediction:9 confidence:63.59%
#  target:1 prediction:1 confidence:99.76%
#  target:2 prediction:2 confidence:86.86%
#  target:4 prediction:4 confidence:99.49%
#  target:2 prediction:2 confidence:78.81%
#  target:3 prediction:3 confidence:99.85%
#  target:13 prediction:13 confidence:99.88%
#  target:9 prediction:9 confidence:86.98%
#  target:1 prediction:1 confidence:99.45%
#  target:13 prediction:13 confidence:98.59%
#  target:7 prediction:7 confidence:99.23%
#  target:2 prediction:2 confidence:97.14%
#  target:2 prediction:2 confidence:96.36%
#  target:10 prediction:10 confidence:94.62%
#  target: 1 prediction: 9 confidence: 41.28%
#  target:4 prediction:4 confidence:99.83%
#  target:8 prediction:8 confidence:99.93%
#  target:11 prediction:11 confidence:99.92%
#  target:3 prediction:3 confidence:99.63%
#  target:10 prediction:10 confidence:99.03%
#  target:13 prediction:13 confidence:98.97%
#  target:10 prediction:10 confidence:99.48%
#  target:1 prediction:1 confidence:89.32%
#  target:10 prediction:10 confidence:64.93%
#  target:1 prediction:1 confidence:98.32%
#  target:6 prediction:6 confidence:99.43%
#  target:11 prediction:11 confidence:99.8%
#  target:0 prediction:0 confidence:99.73%
#  target:6 prediction:6 confidence:99.62%
#  target:4 prediction:4 confidence:95.72%
#  target:12 prediction:12 confidence:99.75%
#  target:0 prediction:0 confidence:99.43%
#  target: 10 prediction: 6 confidence: 44.95%
#  target:2 prediction:2 confidence:99.97%
#  target:5 prediction:5 confidence:99.44%
#  target:0 prediction:0 confidence:99.63%
#  target:0 prediction:0 confidence:99.19%
#  target:13 prediction:13 confidence:99.87%
#  target:6 prediction:6 confidence:94.04%
#  target:2 prediction:2 confidence:63.25%
#  target:10 prediction:10 confidence:99.64%
#  target:12 prediction:12 confidence:99.71%
#  target:0 prediction:0 confidence:96.67%
#  target:7 prediction:7 confidence:99.57%
#  target:6 prediction:6 confidence:66.44%
#  target:10 prediction:10 confidence:72.34%
#  target:3 prediction:3 confidence:99.61%
#  target:6 prediction:6 confidence:98.2%
#  target:10 prediction:10 confidence:93.79%
#  target: 10 prediction: 6 confidence: 74.56%
#  target:5 prediction:5 confidence:99.78%
#  target:3 prediction:3 confidence:99.97%
#  target:7 prediction:7 confidence:97.62%
#  target:9 prediction:9 confidence:98.28%
#  target:7 prediction:7 confidence:98.85%
#  target:8 prediction:8 confidence:99.79%
#  target:1 prediction:1 confidence:99.97%
#  target:0 prediction:0 confidence:99.85%
#  target:5 prediction:5 confidence:91.86%
#  target:5 prediction:5 confidence:99.53%
#  target:8 prediction:8 confidence:99.99%
#  target: 10 prediction: 6 confidence: 57.57%
#  target:4 prediction:4 confidence:99.02%
#  target:2 prediction:2 confidence:99.65%
#  target: 10 prediction: 6 confidence: 55.11%
#  target:3 prediction:3 confidence:99.74%
#  target:11 prediction:11 confidence:89.83%
#  target:12 prediction:12 confidence:99.29%
#  target:9 prediction:9 confidence:86.93%
#  target:5 prediction:5 confidence:99.62%
#  target:10 prediction:10 confidence:98.26%
#  target:8 prediction:8 confidence:99.95%
#  target:5 prediction:5 confidence:98.15%
#  target:4 prediction:4 confidence:87.78%
#  target:5 prediction:5 confidence:98.58%
#  target:1 prediction:1 confidence:99.67%
#  target:1 prediction:1 confidence:99.96%
#  target:6 prediction:6 confidence:99.48%
#  target:4 prediction:4 confidence:99.27%
#  target:8 prediction:8 confidence:99.89%
#  target: 6 prediction: 10 confidence: 97.63%
#  target:7 prediction:7 confidence:96.09%
#  target:3 prediction:3 confidence:99.99%
#  target:12 prediction:12 confidence:99.99%
#  target:2 prediction:2 confidence:98.32%
#  target:9 prediction:9 confidence:99.69%
#  target:7 prediction:7 confidence:99.35%
#  target: 5 prediction: 2 confidence: 99.28%
#  target:1 prediction:1 confidence:99.84%
#  target:10 prediction:10 confidence:99.82%
#  target:2 prediction:2 confidence:99.83%
#  target:6 prediction:6 confidence:82.91%
#  target:7 prediction:7 confidence:86.67%
#  target:7 prediction:7 confidence:94.06%
#  target:4 prediction:4 confidence:99.77%
#  target:9 prediction:9 confidence:98.61%
#  target:4 prediction:4 confidence:98.24%
#  target:8 prediction:8 confidence:99.67%
#  target:4 prediction:4 confidence:99.6%
#  target:12 prediction:12 confidence:97.23%
#  target: 2 prediction: 5 confidence: 55.34%
#  target:8 prediction:8 confidence:98.91%
#  target:12 prediction:12 confidence:99.88%
#  target:10 prediction:10 confidence:99.5%
#  target:7 prediction:7 confidence:88.24%
#  target:0 prediction:0 confidence:99.81%
#  target:1 prediction:1 confidence:99.72%
#  target:3 prediction:3 confidence:99.49%
#  target:7 prediction:7 confidence:80.08%
#  target:13 prediction:13 confidence:99.97%
#  target:7 prediction:7 confidence:99.91%
#  target: 2 prediction: 1 confidence: 99.08%
#  target:7 prediction:7 confidence:98.96%
#  target:4 prediction:4 confidence:99.16%
#  target:5 prediction:5 confidence:99.86%
#  target:3 prediction:3 confidence:99.96%
#  target:3 prediction:3 confidence:99.6%
#  target:12 prediction:12 confidence:99.89%
#  target:7 prediction:7 confidence:94.85%
#  target:1 prediction:1 confidence:99.72%
#  target:9 prediction:9 confidence:55.22%
#  target:6 prediction:6 confidence:71.27%
#  target:5 prediction:5 confidence:99.56%
#  target:12 prediction:12 confidence:99.19%
#  target:8 prediction:8 confidence:99.71%
#  target:13 prediction:13 confidence:98.05%
#  target:0 prediction:0 confidence:99.65%
#  target:2 prediction:2 confidence:64.97%
#  target:6 prediction:6 confidence:99.86%
#  target:7 prediction:7 confidence:94.71%
#  target:3 prediction:3 confidence:99.86%
#  target:11 prediction:11 confidence:99.89%
#  target:5 prediction:5 confidence:99.84%
#  target:8 prediction:8 confidence:99.87%
#  target:0 prediction:0 confidence:99.93%
#  target:1 prediction:1 confidence:97.1%
#  target:1 prediction:1 confidence:99.74%
#  target:1 prediction:1 confidence:99.7%
#  target: 6 prediction: 12 confidence: 32.54%
#  target:5 prediction:5 confidence:99.47%
#  target:4 prediction:4 confidence:99.82%
#  target: 2 prediction: 9 confidence: 61.48%
#  target:11 prediction:11 confidence:99.94%
#  target:9 prediction:9 confidence:99.78%
#  target:12 prediction:12 confidence:99.93%
#  target:0 prediction:0 confidence:85.54%
#  target:12 prediction:12 confidence:98.88%
#  target:8 prediction:8 confidence:99.94%
#  target:12 prediction:12 confidence:99.48%
#  target:3 prediction:3 confidence:99.97%
#  target:2 prediction:2 confidence:98.08%
#  target:5 prediction:5 confidence:90.62%
#  target:0 prediction:0 confidence:99.78%
#  target:10 prediction:10 confidence:99.84%
#  target:4 prediction:4 confidence:99.65%
#  target:11 prediction:11 confidence:99.78%
#  target:13 prediction:13 confidence:99.53%
#  target:7 prediction:7 confidence:88.34%
#  target:10 prediction:10 confidence:97.01%
#  target:5 prediction:5 confidence:99.74%
#  target:8 prediction:8 confidence:99.94%
#  target:4 prediction:4 confidence:99.82%
#  target:9 prediction:9 confidence:86.33%
#  target:9 prediction:9 confidence:99.43%
#  target:8 prediction:8 confidence:100.0%
#  target:0 prediction:0 confidence:99.86%
#  target:9 prediction:9 confidence:80.95%
#  target:10 prediction:10 confidence:99.33%
#  target:5 prediction:5 confidence:99.84%
#  target:0 prediction:0 confidence:99.78%
#  target:12 prediction:12 confidence:99.84%
#  target:6 prediction:6 confidence:99.2%
#  target:12 prediction:12 confidence:99.93%
#  target: 10 prediction: 6 confidence: 62.02%
#  target:5 prediction:5 confidence:99.48%
#  target:9 prediction:9 confidence:78.51%
#  target:13 prediction:13 confidence:99.9%
#  target:13 prediction:13 confidence:99.66%
#  target:10 prediction:10 confidence:92.03%
#  target:7 prediction:7 confidence:99.98%
#  target:3 prediction:3 confidence:99.95%
#  target:11 prediction:11 confidence:99.71%
#  target:9 prediction:9 confidence:84.79%
#  target:9 prediction:9 confidence:99.23%
#  target:0 prediction:0 confidence:99.94%
#  target:10 prediction:10 confidence:57.76%
#  target:1 prediction:1 confidence:99.9%
#  target:13 prediction:13 confidence:99.51%
#  target:11 prediction:11 confidence:99.97%
#  target:11 prediction:11 confidence:99.31%
#  target:4 prediction:4 confidence:99.09%
#  target: 6 prediction: 8 confidence: 52.16%
#  target:4 prediction:4 confidence:96.69%
#  target:13 prediction:13 confidence:99.87%
#  target:11 prediction:11 confidence:99.97%
#  target:8 prediction:8 confidence:100.0%
#  target:2 prediction:2 confidence:96.74%
#  target:1 prediction:1 confidence:73.02%
#  target:0 prediction:0 confidence:99.98%
#  target:7 prediction:7 confidence:99.8%
#  target:2 prediction:2 confidence:94.63%
#  target:10 prediction:10 confidence:98.54%
#  target:5 prediction:5 confidence:98.75%
#  target:4 prediction:4 confidence:99.65%
#  target: 2 prediction: 1 confidence: 93.0%
#  target: 2 prediction: 8 confidence: 74.98%
#  target:6 prediction:6 confidence:44.84%
#  target:13 prediction:13 confidence:99.4%
#  target:9 prediction:9 confidence:99.87%
#  target:10 prediction:10 confidence:97.88%
#  target:3 prediction:3 confidence:99.99%
#  target:10 prediction:10 confidence:96.87%
#  target:7 prediction:7 confidence:99.46%
#  target:12 prediction:12 confidence:99.61%
#  target:4 prediction:4 confidence:98.49%
#  target:9 prediction:9 confidence:99.1%
#  target:5 prediction:5 confidence:99.95%
#  target:11 prediction:11 confidence:98.63%
#  target:2 prediction:2 confidence:69.58%
#  target:11 prediction:11 confidence:97.95%
#  target:2 prediction:2 confidence:59.99%
#  target:6 prediction:6 confidence:99.74%
#  target:2 prediction:2 confidence:99.14%
#  target:6 prediction:6 confidence:80.92%
#  target:12 prediction:12 confidence:99.74%
#  target:2 prediction:2 confidence:80.31%
#  target:4 prediction:4 confidence:99.69%
#  target:11 prediction:11 confidence:95.5%
#  target:5 prediction:5 confidence:99.98%
#  target:0 prediction:0 confidence:99.96%
#  target:12 prediction:12 confidence:99.91%
#  target:10 prediction:10 confidence:99.86%
#  target:2 prediction:2 confidence:97.89%
#  target:4 prediction:4 confidence:85.6%
#  target: 2 prediction: 1 confidence: 40.57%
#  target:8 prediction:8 confidence:99.1%
#  target:8 prediction:8 confidence:99.95%
#  target:9 prediction:9 confidence:99.32%
#  target:5 prediction:5 confidence:92.5%
#  target:4 prediction:4 confidence:97.07%
#  target:7 prediction:7 confidence:80.33%
#  target:12 prediction:12 confidence:95.13%
#  target:7 prediction:7 confidence:99.36%
#  target:11 prediction:11 confidence:95.45%
#  target:5 prediction:5 confidence:97.14%
#  target:13 prediction:13 confidence:99.99%
#  target:11 prediction:11 confidence:99.72%
#  target:7 prediction:7 confidence:99.44%
#  target:4 prediction:4 confidence:99.73%
#  target:0 prediction:0 confidence:73.9%
#  target:2 prediction:2 confidence:99.93%
#  target:1 prediction:1 confidence:92.82%
#  target:6 prediction:6 confidence:56.74%
#  target:4 prediction:4 confidence:99.42%
#  target:11 prediction:11 confidence:99.74%
#  target:13 prediction:13 confidence:99.53%
#  target:12 prediction:12 confidence:95.17%
#  target:0 prediction:0 confidence:99.99%
#  target:11 prediction:11 confidence:99.8%
#  target:11 prediction:11 confidence:97.26%
#  target:1 prediction:1 confidence:89.33%
#  target:4 prediction:4 confidence:96.64%
#  target:12 prediction:12 confidence:99.57%
#  target:13 prediction:13 confidence:99.79%
#  target:1 prediction:1 confidence:98.4%
#  Accuracy: 90.38461538461539
#  Test accuracy
#
#
#  target: 4 prediction: 0 confidence: 38.78%
#  target: 3 prediction: 12 confidence: 56.66%
#  target: 2 prediction: 11 confidence: 38.36%
#  target: 1 prediction: 8 confidence: 76.19%
#  target: 0 prediction: 10 confidence: 69.49%
#  target: 0 prediction: 1 confidence: 54.72%
#  target: 3 prediction: 2 confidence: 31.26%
#  target: 3 prediction: 12 confidence: 92.85%
#  target: 2 prediction: 6 confidence: 81.35%
#  target: 0 prediction: 8 confidence: 44.98%
#  target: 2 prediction: 6 confidence: 88.04%
#  target: 3 prediction: 2 confidence: 89.08%
#  target: 4 prediction: 3 confidence: 37.35%
#  target: 4 prediction: 8 confidence: 41.19%
#  target: 3 prediction: 4 confidence: 30.11%
#  target: 3 prediction: 2 confidence: 74.82%
#  target: 1 prediction: 10 confidence: 97.36%
#  target: 0 prediction: 8 confidence: 65.68%
#  target: 3 prediction: 9 confidence: 47.45%
#  target: 4 prediction: 7 confidence: 97.54%
#  target: 6 prediction: 2 confidence: 28.96%
#  target: 4 prediction: 9 confidence: 91.68%
#  target: 2 prediction: 0 confidence: 72.93%
#  target: 6 prediction: 2 confidence: 56.11%
#  target: 3 prediction: 12 confidence: 90.78%
#  target: 3 prediction: 13 confidence: 81.15%
#  target: 2 prediction: 8 confidence: 22.56%
#  target: 2 prediction: 1 confidence: 40.01%
#  target: 3 prediction: 5 confidence: 77.67%
#  target: 5 prediction: 8 confidence: 99.9%
#  target: 3 prediction: 13 confidence: 30.28%
#  target: 3 prediction: 12 confidence: 58.81%
#  target: 0 prediction: 9 confidence: 36.66%
#  target: 0 prediction: 7 confidence: 86.92%
#  target: 6 prediction: 12 confidence: 99.59%
#  target: 0 prediction: 7 confidence: 43.84%
#  target: 5 prediction: 6 confidence: 77.72%
#  target: 6 prediction: 11 confidence: 26.52%
#  target: 1 prediction: 10 confidence: 99.56%
#  target: 4 prediction: 7 confidence: 94.88%
#  target: 6 prediction: 0 confidence: 30.02%
#  target: 1 prediction: 10 confidence: 75.76%
#  target: 3 prediction: 2 confidence: 99.93%
#  target: 4 prediction: 5 confidence: 95.06%
#  target: 0 prediction: 7 confidence: 75.83%
#  target: 5 prediction: 8 confidence: 92.11%
#  target: 2 prediction: 5 confidence: 58.48%
#  target: 1 prediction: 3 confidence: 91.91%
#  target: 4 prediction: 0 confidence: 44.73%
#  target: 2 prediction: 3 confidence: 58.57%
